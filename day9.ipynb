# %%
#bank account

# %%
class BankAccount:

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print("Amount Deposited:", amount)

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print("Amount Withdrawn:", amount)
        else:
            print("Insufficient Balance")

    def view_balance(self):
        print("Current Balance:", self.balance)

    def calculator(self):
        a = float(input("Enter first number: "))
        b = float(input("Enter second number: "))
        op = input("Enter operation (+,-,*,/): ")

        if op == "+":
            print("Result =", a + b)
        elif op == "-":
            print("Result =", a - b)
        elif op == "*":
            print("Result =", a * b)
        elif op == "/":
            print("Result =", a / b)
        else:
            print("Invalid Operation")

 # Dynamic Object Creation
 
name = input("Enter Account Holder Name: ")
balance = float(input("Enter Initial Balance: "))

acc = BankAccount(name, balance)

while True:
    print("\n1. Deposit")
    print("2. Withdraw")
    print("3. View Balance")
    print("4. Calculator")
    print("5. Exit")

    choice = int(input("Enter Choice: "))

    if choice == 1:
        amount = float(input("Enter Deposit Amount: "))
        acc.deposit(amount)

    elif choice == 2:
        amount = float(input("Enter Withdraw Amount: "))
        acc.withdraw(amount)

    elif choice == 3:
        acc.view_balance()

    elif choice == 4:
        acc.calculator()

    elif choice == 5:
        print("Thank You!")
        break

    else:
        print("Invalid Choice")
# Out:
# 1. Deposit
# 2. Withdraw
# 3. View Balance
# 4. Calculator
# 5. Exit
# Current Balance: 2000.0
#
# 1. Deposit
# 2. Withdraw
# 3. View Balance
# 4. Calculator
# 5. Exit
# Amount Withdrawn: 1000.0
#
# 1. Deposit
# 2. Withdraw
# 3. View Balance
# 4. Calculator
# 5. Exit
# Insufficient Balance
#
# 1. Deposit
# 2. Withdraw
# 3. View Balance
# 4. Calculator
# 5. Exit
# Invalid Operation
#
# 1. Deposit
# 2. Withdraw
# 3. View Balance
# 4. Calculator
# 5. Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 51
#      47     print("3. View Balance")
#      48     print("4. Calculator")
#      49     print("5. Exit")
#      50
# ---> 51     choice = int(input("Enter Choice: "))
#      52
#      53     if choice == 1:
#      54         amount = float(input("Enter Deposit Amount: "))
#
# ValueError: invalid literal for int() with base 10: '+'

# %%
#studnt and their courses enrollment function

# %%
class Student:

    def __init__(self, name, roll_no):
        self.name = name
        self.roll_no = roll_no
        self.courses = []

    def enroll_course(self):
        course = input("Enter Course Name: ")
        self.courses.append(course)
        print(course, "enrolled successfully!")

    def view_courses(self):
        print("\nStudent Name:", self.name)
        print("Roll No:", self.roll_no)
        print("Enrolled Courses:", self.courses)


# Dynamic Object Creation
name = input("Enter Student Name: ")
roll = input("Enter Roll Number: ")

s = Student(name, roll)

while True:
    print("\n1. Enroll Course")
    print("2. View Courses")
    print("3. Exit")

    choice = int(input("Enter Choice: "))

    if choice == 1:
        s.enroll_course()

    elif choice == 2:
        s.view_courses()

    elif choice == 3:
        print("Thank You!")
        break

    else:
        print("Invalid Choice")
# Out:
# 1. Enroll Course
# 2. View Courses
# 3. Exit
#
# Student Name: mayank
# Roll No: 1824
# Enrolled Courses: []
#
# 1. Enroll Course
# 2. View Courses
# 3. Exit
# Thank You!
