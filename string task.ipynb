# %%
name="python programming language"
print(name[0])
print(name[4])
print(name[8])
# Out:
# p
# o
# r

# %%
#string slicing
#start,end,skip

# %%
name="python programming language"
print(len(name))
print(name.lower())
print(name.upper())
print(name.capitalize())
print(name.title())
print(name.replace("python","java"))
print(name.count("m"))
print(name.index("n"))
# Out:
# 27
# python programming language
# PYTHON PROGRAMMING LANGUAGE
# Python programming language
# Python Programming Language
# java programming language
# 2
# 5

# %%
#list(anything can be change)

# %%
fruits=["apple","banana","mango","orange"]
print(fruits[3])
# Out:
# orange

# %%
#list slicing

# %%
numbers=[10,40,50,80,20,110]
print(numbers[0:3])
print(numbers[::-1])
# Out:
# [10, 40, 50]
# [110, 20, 80, 50, 40, 10]

# %%
#list functions

# %%
fruits.append("apple")
print(fruits)
fruits.remove("banana")
fruits.pop(3)
# Out:
# ['apple', 'banana', 'mango', 'orange', 'apple']
# 'apple'

# %%
#tuples(anything can not be change)

# %%
cities=("delhi","yamunanager","mumbai","kolkata")
print(cities[2])
# Out:
# mumbai

# %%
#tuples slicing

# %%
print(cities[0:2])
# Out:
# ('delhi', 'yamunanager')
