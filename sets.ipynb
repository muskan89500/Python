# %%
#set-a et is a collection of unique value

# %%
numbers = {10,20,30,40,50,20,20,50,40}

# %%
print(numbers)
# Out:
# {50, 20, 40, 10, 30}

# %%
#set functions

# %%
fruits = {"apple","mango"}
fruits.add("orange")

# %%
print(fruits)
# Out:
# {'apple', 'orange', 'mango'}

# %%
fruits.remove("mango")

# %%
print(fruits)
# Out:
# {'apple', 'orange'}

# %%
print(len(fruits))
# Out:
# 2

# %%
a ={1,2,3}

# %%
b ={3,4,5}

# %%
print(a.intersection(b))
print(a.difference(b))
print(b.difference(a))
# Out:
# {3}
# {1, 2}
# {4, 5}

# %%
#dictionaries

# %%
student ={
    "name":"muskan",
    "age":"20",
    "marks":"86"
}

# %%
print(student)
# Out:
# {'name': 'muskan', 'age': '20', 'marks': '86'}

# %%
#access element

# %%
print(student["name"])
# Out:
# muskan

# %%
print(student["marks"])
# Out:
# 86

# %%
#add

# %%
student['city'] = "delhi"
print(student)
# Out:
# {'name': 'muskan', 'age': '20', 'marks': '86', 'city': 'delhi'}

# %%
#update

# %%
student["marks"] =95
print(student)
# Out:
# {'name': 'muskan', 'age': '20', 'marks': 95, 'city': 'delhi'}

# %%
#delete

# %%
del student["age"]
print(student)
# Out:
# {'name': 'muskan', 'marks': 95, 'city': 'delhi'}

# %%
print(student.keys())
print(student.values())
# Out:
# dict_keys(['name', 'marks', 'city'])
# dict_values(['muskan', 95, 'delhi'])

# %%
print(student.items())
# Out:
# dict_items([('name', 'muskan'), ('marks', 95), ('city', 'delhi')])

# %%
print(len(student))
# Out:
# 3
