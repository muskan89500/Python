# %%
name = input("enter your name: ")
rollno = input("enter your rollno: ")
maths = input("enter your maths marks: ")
loc = input("enter your loc marks: ")
web = input("enter your web marks: ")
print("name is:", name)
print("rollno is:", rollno)
print("maths is:", maths)
print("loc is:", loc)
print("web is:", web)
# Out:
# name is: muskan
# rollno is: 1768
# maths is: 48
# loc is: 47
# web is: 46
